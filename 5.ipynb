# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd

def scrape_weather_data(year, month):
    url = f"https://www.data.jma.go.jp/stats/etrn/view/daily_s1.php?prec_no=44&block_no=47662&year={year}&month={month}&day=&view=p1"
    response = requests.get(url)
    soup = BeautifulSoup(response.content, 'html.parser')
    table = soup.find('table', {'class': 'data2_s'})
    rows = table.find_all('tr')[2:]

    data = []
    for row in rows:
        cols = row.find_all('td')
        data_row = [col.text.strip() for col in cols]
        data.append(data_row)

    columns = ["Day", "Local Pressure", "Sea Level Pressure", "Total Precipitation", "1h Precipitation",
               "10min Precipitation", "Average Temperature", "Max Temperature", "Min Temperature",
               "Average Humidity", "Min Humidity", "Average Wind Speed", "Max Wind Speed",
               "Max Wind Direction", "Max Instant Wind Speed", "Max Instant Wind Direction",
               "Sunshine Duration", "Snowfall", "Deepest Snow", "Daytime Weather", "Night Weather"]
    df = pd.DataFrame(data, columns=columns)
    return df

weather_data_december_2023 = scrape_weather_data(2023, 12)

print(weather_data_december_2023)
# Out:
# /Users/beetlea/lecture/Mydata/MD/MD2_no6_practice/MD2_for_data56/lib/python3.9/site-packages/urllib3/__init__.py:34: NotOpenSSLWarning: urllib3 v2.0 only supports OpenSSL 1.1.1+, currently the 'ssl' module is compiled with 'LibreSSL 2.8.3'. See: https://github.com/urllib3/urllib3/issues/3020
#   warnings.warn(
#      Day Local Pressure Sea Level Pressure Total Precipitation  \
# 0   None           None               None                None
# 1   None           None               None                None
# 2      1         1012.3             1015.2                  --
# 3      2         1015.6             1018.5                  --
# 4      3         1015.5             1018.5                  --
# 5      4         1018.2             1021.2                  --
# 6      5         1016.3             1019.3                 0.0
# 7      6         1008.8             1011.8                 1.0
# 8      7         1004.1             1006.9                  --
# ...

# %%
weather_data_december_2023.head()
# Out:
#     Day Local Pressure Sea Level Pressure Total Precipitation  \
# 0  None           None               None                None
# 1  None           None               None                None
# 2     1         1012.3             1015.2                  --
# 3     2         1015.6             1018.5                  --
# 4     3         1015.5             1018.5                  --
#
#   1h Precipitation 10min Precipitation Average Temperature Max Temperature  \
# 0             None                None                None            None
# 1             None                None                None            None
# 2               --                  --                 8.7            12.6
# 3               --                  --                 8.3            13.1
# 4               --                  --                 9.1            15.2
#
#   Min Temperature Average Humidity  ... Average Wind Speed Max Wind Speed  \
# ...

# %%
weather_data_december_2023.describe()
# Out:
#        Day Local Pressure Sea Level Pressure Total Precipitation  \
# count   31             31                 31                  31
# unique  31             28                 27                   6
# top      1         1018.2             1021.2                  --
# freq     1              3                  3                  24
#
#        1h Precipitation 10min Precipitation Average Temperature  \
# count                31                  31                  31
# unique                5                   4                  27
# top                  --                  --                 7.0
# freq                 23                  24                   3
#
#        Max Temperature Min Temperature Average Humidity  ...  \
# count               31              31               31  ...
# unique              27              26               26  ...
# top               12.6             7.1               36  ...
# freq                 2               3                2  ...
#
# ...

# %%
display(weather_data_december_2023)
# Out:
#      Day Local Pressure Sea Level Pressure Total Precipitation  \
# 0   None           None               None                None
# 1   None           None               None                None
# 2      1         1012.3             1015.2                  --
# 3      2         1015.6             1018.5                  --
# 4      3         1015.5             1018.5                  --
# 5      4         1018.2             1021.2                  --
# 6      5         1016.3             1019.3                 0.0
# 7      6         1008.8             1011.8                 1.0
# 8      7         1004.1             1006.9                  --
# 9      8         1016.3             1019.2                  --
# 10     9         1017.0             1019.9                  --
# 11    10         1018.5             1021.4                  --
# 12    11         1019.6             1022.5                 0.5
# 13    12         1007.6             1010.5                15.5
# ...
